# %%
def list_to_string(input_list):
    if not input_list:
        return ""
    else:
        return input_list[0] + list_to_string(input_list[1:])

input_list = ['p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g']
output_string = list_to_string(input_list)

print(output_string)
# Out:
# programming
